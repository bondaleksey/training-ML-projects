# %%
from authors import str_of_keldysh_authors
import re
print(len(str_of_keldysh_authors))
# Out:
# 186956

# %%
authors = re.split(r'[()]',str_of_keldysh_authors)
print(len(authors))
# Out:
# 11237

# %%
print(authors)
# Out:
# ['Лахно Виктор Дмитриевич  ', '484', '\n\tМалинецкий Георгий Геннадьевич  ', '368', '\n\tБалабаев Николай Кириллович  ', '337', '\n\tСазонов Виктор Васильевич  ', '292', '\n\tБрюно Александр Дмитриевич  ', '290', '\n\tОвчинников Михаил Юрьевич  ', '254', '\n\tЧечёткин Валерий Михайлович  ', '245', '\n\tЧетверушкин Борис Николаевич  ', '222', '\n\tОрлов Юрий Николаевич  ', '209', '\n\tТишкин Владимир Федорович  ', '209', '\n\tКалиткин Николай Николаевич  ', '207', '\n\tГаланин Михаил Павлович  ', '187', '\n\tУстинин Михаил Николаевич  ', '186', '\n\tМолчанов Альберт Макарьевич  ', '185', '\n\tГалактионов Владимир Александрович  ', '181', '\n\tВолобой Алексей Геннадьевич  ', '170', '\n\tЛунин Владимир Юрьевич  ', '170', '\n\tГасилов Владимир Анатольевич  ', '166', '\n\tГолубев Юрий Филиппович  ', '165', '\n\tБондарев Александр Евгеньевич  ', '160', '\n\tМахортых Сергей Александрович  ', '153', '\n\tШноль Эммануил Эльевич  ', '150', '\n\tПавловский Владимир Евгеньевич  ', '145', '\n\tТу
# ...
